# %% [markdown]
# <a href="https://colab.research.google.com/github/keesterbrugge/rl_intro_sutton/blob/main/ch5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
# xr.DataArray()

track = np.ones((32,17))
track[:-6, 10:] = 0
track[-7,10] = 1
# left upper corner
track[-4:, 0] = 0
track[-3:, 1] = 0
track[-1, 2] = 0
track[:18, 0] = 0
track[:10, 1] = 0
track[:3, 2] = 0



fig, ax = plt.subplots()

im = ax.imshow(track, origin="lower")
ax.set_xticks(np.arange(0-.5, 17-.5, 1), minor=True)
ax.set_yticks(np.arange(0-.5, 32-.5, 1), minor=True)

ax.grid(which="minor", color='black', linestyle='-', linewidth=.5)
  # Create colorbar
# cbar = ax.figure.colorbar(im, ax=ax)
# cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

# %%
# init
S_position = np.transpose(np.nonzero(track))
S_speed = 
action_space = lambda s: if s[0] == 0 else np.arange(1,5)
# Out:
#   File "<ipython-input-3-fa852e0b0047>", line 3
#     S_speed =
#               ^
# SyntaxError: invalid syntax

# %%
# Q = xr.DataArray(np.random.rand(5,3), coords=[np.arange(0,5), [-1, 0, 1]], dims=["position", "speed_change"])
# Q

# %%
Q.idxmax(dim="speed_change")
# Out:
# <xarray.DataArray 'speed_change' (position: 5)>
# array([ 1.,  0.,  0.,  1., -1.])
# Coordinates:
#   * position  (position) int64 0 1 2 3 4

# %%
eps = 0.1

# %%
n_actions = 9

action_space = np.ones(n_actions)/n_actions
action_space
# Out:
# array([0.11111111, 0.11111111, 0.11111111, 0.11111111, 0.11111111,
#        0.11111111, 0.11111111, 0.11111111, 0.11111111])

# %%
s_a_shape = (track.size, n_actions) 
Q = dict()#np.ones(s_a_shape)
returns = dict()
R_sum = np.zeros(s_a_shape)
N_sum = np.zeros(s_a_shape)

# %%
from re import I
done = False
counter = 0
while not done:
  counter += 1
  print(counter)

  (S, A, R) = gen_episodes(Q, state) # use Q and eps for choosing eps
  G = 0
  for ... t-1 : 0: # till zero
      G = gamma ( G + r_t+1)
      for ii in range(i):
        if (S[ii]==s) & (A[ii]==a):
          break
      R_sum += r
      N_sum += 1
      Q[s, a] = R_sum[s,a] / N_sum[s,a]
      # A_star = Q.argmax(axis = ,ties broken randomly) don't have to do this
